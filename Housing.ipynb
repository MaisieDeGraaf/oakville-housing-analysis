# %%
# import dependencies

import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
import os
from pathlib import Path
import csv

# %%
# Read the census data into a Pandas DataFrame
file_path = Path("Data/Oakville_2021.csv")
data = pd.read_csv(file_path, encoding="ISO-8859-1", low_memory=True)
#data = pd.read_csv(file_path, encoding="UTF-8", index_col="year")
data
# Out:
#                                                   Topic  \
# 0                              Population and dwellings
# 1                              Population and dwellings
# 2                              Population and dwellings
# 3                              Population and dwellings
# 4                              Population and dwellings
# ...                                                 ...
# 2626  Eligibility and instruction in the minority of...
# 2627  Eligibility and instruction in the minority of...
# 2628  Eligibility and instruction in the minority of...
# 2629  Eligibility and instruction in the minority of...
# 2630  Eligibility and instruction in the minority of...
#
#                                          Characteristic     Total Total_Flag  \
# 0                                      Population, 2021  213759.0        NaN
# 1                                      Population, 2016  193832.0        NaN
# ...
